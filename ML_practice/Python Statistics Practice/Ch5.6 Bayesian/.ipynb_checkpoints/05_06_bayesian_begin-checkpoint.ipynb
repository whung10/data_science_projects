# %% [markdown]
# ## Python statistics essential training - 05_06_bayesian

# %% [markdown]
# Standard imports

# %%
import math

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

# %%
# %matplotlib inline

# %%
import pymc3 as pm
# Out:
# /anaconda3/lib/python3.7/site-packages/theano/configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
n = 100
k = 61

with pm.Model() as coin_contect:
    p = pm.Uniform('p', 0.40, 0.80)
    y = pm.Binomial('y', n=n, p=p, observed=k)
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [p]
# Sampling 2 chains: 100%|██████████| 21000/21000 [00:49<00:00, 425.65draws/s]

# %%
 pm.summary(trace)
# Out:
#        mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff      Rhat
# p  0.608246  0.048344  0.000561  0.512584  0.701719  7702.921846  1.000156

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1183d46a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118447da0>]],
#       dtype=object)

# %%
gdata = pd.read_csv('gapminder.csv').query('year == 1985')

# %%
gdata.sort_values('age5_surviving', inplace=True)

# %%
pp.scatter(gdata['age5_surviving'], gdata['babies_per_woman'])

# %%
with pm.Model() as gapminder_context:
    intercept = pm.Uniform('intercept', 5, 15)
    slope = pm.Uniform('slope', -1, 1)
    
    babies = pm.Normal('babies',
                        mu = intercept + slope * (gdata['age5_surviving'] - 65),
                        sd = 1,
                        observed = gdata['babies_per_woman'])
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [slope, intercept]
# Sampling 2 chains: 100%|██████████| 21000/21000 [1:22:41<00:00,  4.23draws/s]
# The acceptance probability does not match the target. It is 0.8957952725860929, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.summary(trace)
# Out:
#                 mean        sd  mc_error   hpd_2.5   hpd_97.5        n_eff  \
# intercept  10.190061  0.284006  0.004278  9.653787  10.757095  3957.565604
# slope      -0.219104  0.010277  0.000159 -0.239030  -0.199565  3952.536411
#
#                Rhat
# intercept  1.000179
# slope      1.000235

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c23076198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2294d4e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c22ebdba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c22cc19b0>]],
#       dtype=object)
